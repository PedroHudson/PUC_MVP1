# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroHudson/PUC_MVP1/blob/main/MVP_teste1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importacao do pandas
import pandas as pd

# Importacao do Numpy
import numpy as np

# %%
# importando dados de uma url para um dataframe

# url a importar
url_dados = 'https://www.gov.br/receitafederal/dados/arrecadacao-estado.csv?raw=true'

# carga do dataset atraves da url
ipi = pd.read_csv(url_dados, sep=';',encoding='ISO-8859-1',decimal=',')

ipi_cols1=ipi[['Ano','UF','IPI - FUMO','IPI - BEBIDAS', 'IPI - AUTOMÓVEIS']]

ipi_cols1.dtypes
# Out:
# Ano                  int64
# UF                  object
# IPI - FUMO          object
# IPI - BEBIDAS       object
# IPI - AUTOMÓVEIS    object
# dtype: object

# %%
ipi_cols1['IPI - FUMO']=ipi_cols1['IPI - FUMO'].str.replace(',','').astype(int)

ipi_cols1.describe()
# Out:
# <ipython-input-82-36f81d0f6d85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipi_cols1['IPI - FUMO']=ipi_cols1['IPI - FUMO'].str.replace(',','').astype(int)
#          IPI - FUMO  IPI - BEBIDAS  IPI - AUTOMÓVEIS
# count  7.506000e+03   7.506000e+03      7.506000e+03
# mean   1.723666e+08   4.153927e+08      3.363824e+08
# std    8.304751e+08   1.039483e+09      1.148966e+09
# min   -4.329186e+08  -1.079723e+07     -1.454896e+08
# 25%    0.000000e+00   2.113774e+06      0.000000e+00
# 50%    6.305280e+05   1.780597e+07      6.004000e+03
# 75%    5.835088e+06   3.013147e+08      6.257185e+06
# max    9.904761e+09   9.945420e+09      9.967381e+09

# %%
#ipi_cols1['IPI - BEBIDAS']=ipi_cols1['IPI - BEBIDAS'].str.replace(',','').astype(int)

ipi_cols1.describe()
# Out:
#          IPI - FUMO  IPI - BEBIDAS  IPI - AUTOMÓVEIS
# count  7.506000e+03   7.506000e+03      7.506000e+03
# mean   1.723666e+08   4.153927e+08      3.363824e+08
# std    8.304751e+08   1.039483e+09      1.148966e+09
# min   -4.329186e+08  -1.079723e+07     -1.454896e+08
# 25%    0.000000e+00   2.113774e+06      0.000000e+00
# 50%    6.305280e+05   1.780597e+07      6.004000e+03
# 75%    5.835088e+06   3.013147e+08      6.257185e+06
# max    9.904761e+09   9.945420e+09      9.967381e+09

# %%
ipi_cols1['IPI - AUTOMÓVEIS']=ipi_cols1['IPI - AUTOMÓVEIS'].str.replace(',','').astype(int)
# Out:
# <ipython-input-78-af11abd652ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipi_cols1['IPI - AUTOMÓVEIS']=ipi_cols1['IPI - AUTOMÓVEIS'].str.replace(',','').astype(int)

# %%
ipi_cols1.describe()
# Out:
#          IPI - FUMO  IPI - BEBIDAS  IPI - AUTOMÓVEIS
# count  7.506000e+03   7.506000e+03      7.506000e+03
# mean   1.723666e+08   4.153927e+08      3.363824e+08
# std    8.304751e+08   1.039483e+09      1.148966e+09
# min   -4.329186e+08  -1.079723e+07     -1.454896e+08
# 25%    0.000000e+00   2.113774e+06      0.000000e+00
# 50%    6.305280e+05   1.780597e+07      6.004000e+03
# 75%    5.835088e+06   3.013147e+08      6.257185e+06
# max    9.904761e+09   9.945420e+09      9.967381e+09

# %%
ipi_cols1['Ano']=ipi_cols1['Ano'].astype(str)
# Out:
# <ipython-input-85-afebfaa45d3e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipi_cols1['Ano']=ipi_cols1['Ano'].astype(str)

# %%
ipi_cols1.dtypes
# Out:
# Ano                 object
# UF                  object
# IPI - FUMO           int64
# IPI - BEBIDAS        int64
# IPI - AUTOMÓVEIS     int64
# dtype: object

# %%
ipi_cols1.head()
# Out:
#     Ano  UF  IPI - FUMO  IPI - BEBIDAS  IPI - AUTOMÓVEIS
# 0  2000  AC      292096              0                 0
# 1  2000  AL     1329338         812470                 0
# 2  2000  AM     1507146        1791471             27796
# 3  2000  AP      424862           1419               321
# 4  2000  BA     5542123       11533707                 0

# %%
ipi_cols1.tail()
# Out:
#        Ano  UF  IPI - FUMO  IPI - BEBIDAS  IPI - AUTOMÓVEIS
# 7501  2023  RS  1269716012       69733419           2724163
# 7502  2023  SC           0     1237011807        2393873215
# 7503  2023  SE    61762028      148688461                 0
# 7504  2023  SP   201563864     3814353816        1363010272
# 7505  2023  TO           0       36343944            686202

# %%
ipi_cols1.shape
# Out:
# (7506, 4)

# %%
ipi_cols1.count()
# Out:
# Ano                 7506
# UF                  7506
# IPI - FUMO          7506
# IPI - BEBIDAS       7506
# IPI - AUTOMÓVEIS    7506
# dtype: int64

# %%
ipi_cols1 = ipi_cols1[['Ano','UF','IPI - FUMO','IPI - BEBIDAS','IPI - AUTOMÓVEIS']]

# %%
ipi_cols1.dtypes
# Out:
# Ano                 object
# UF                  object
# IPI - FUMO           int64
# IPI - BEBIDAS        int64
# IPI - AUTOMÓVEIS     int64
# dtype: object

# %%
# importacao do pyplot
import matplotlib.pyplot as plt

# %%
# plotando o grafico IPI - FUMO x Ano
plt.scatter(ipi_cols1['UF'], ipi_cols1['IPI - FUMO'])

# incluindo titulos do grafico e rotulos dos eixos
plt.title('IPI - FUMO: Arrecadacao dos ultimos 20 anos') 
plt.xlabel('UF')
plt.ylabel('Valor');

# %%
# graficos de linhas

# selecionando apenas os atributos para serem plotados em um novo dataframe
#atributos = ipi_cols1.columns.drop(['IPI - FUMO'])

# criando o eixo x - vai de 0 ate a qte de linhas do dataset 
x_data = range (0,ipi_cols1.shape[0])

# plotando cada atributo
#for atributo in atributos:

#ipi_cols1[1:11]
  
plt.plot(ipi_cols1['UF'], ipi_cols1['IPI - FUMO']);

# %%
# importacao do seaborn
import seaborn as sns

# %%
#scatter plot com seaborn
sns.scatterplot(x='UF', y='IPI - FUMO', data=ipi_cols1);

# %%
# graficos de linhas com Seaborn
sns.lineplot(data=ipi_cols1.drop(['Ano'], axis=1));

# %%
# boxplot com Seaborn
sns.boxplot(data=ipi_cols1[1:100]);

# %%
# histograma com seaborn
sns.histplot(ipi_cols1['IPI - FUMO'], bins=7);

# %%
# boxplot com Seaborn
sns.boxplot(x=ipi_cols1['IPI - FUMO']);

# %%
# grafico de correlacao com Seaborn
sns.heatmap(ipi_cols1.corr(), annot=True, cmap= 'RdBu', vmin=-1, vmax=1);
# Out:
# <ipython-input-132-19712d30e47b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ipi_cols1.corr(), annot=True, cmap= 'RdBu', vmin=-1, vmax=1);

# %%
# pair plot 1 com Seaborn

sns.pairplot(ipi_cols1);

# %%
# pair plot 2 com seaborn
sns.pairplot(ipi_cols1, hue='Ano');

# %%
# configuracao
